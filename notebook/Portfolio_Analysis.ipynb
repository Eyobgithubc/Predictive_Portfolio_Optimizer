# %%
import pandas as pd
import sys
import os

# %%
sys.path.append(os.path.abspath('C:/Users/teeyob/Predictive_Portfolio_Optimizer/scripts'))

# %%
from portfolio_analysis_functions import (
    calculate_portfolio_return, calculate_portfolio_volatility,
    portfolio_statistics, generate_random_portfolios, plot_efficient_frontier,
    optimize_portfolio, display_optimal_portfolio
)

# %%
from data_analysis_functions import download_data, clean_data, calculate_daily_returns

# %%
tickers = ['TSLA', 'BND', 'SPY']
start_date = '2015-01-01'
end_date = '2024-10-31'

# %% [markdown]
# Download and Clean Data

# %%
data = download_data(tickers, start_date, end_date)
data = clean_data(data)
# Out:
# [*********************100%***********************]  3 of 3 completed
# C:\Users\teeyob\Predictive_Portfolio_Optimizer\scripts\data_analysis_functions.py:19: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)

# %% [markdown]
# Calculate Daily Returns

# %%
returns = calculate_daily_returns(data)

# %% [markdown]
# Generate and Plot Random Portfolios

# %%
num_portfolios = 5000  # Number of random portfolios to simulate
results, weight_matrix = generate_random_portfolios(num_portfolios, returns)
plot_efficient_frontier(results)

# %% [markdown]
# Optimize Portfolio for Maximum Sharpe Ratio

# %%
optimal_weights = optimize_portfolio(returns)
display_optimal_portfolio(optimal_weights, returns)
# Out:
# Optimal Portfolio Return: 0.20
# Optimal Portfolio Volatility: 0.22
# Optimal Portfolio Sharpe Ratio: 0.88
# Optimal Weights: [0.10064454 0.6538197  0.24553576]
